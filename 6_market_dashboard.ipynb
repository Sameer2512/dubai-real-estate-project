-- %%
SELECT month, total_sales_aed 
FROM gold_sales_overview 
ORDER BY month
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT area_name, total_volume_aed 
FROM gold_area_stats
ORDER BY total_volume_aed DESC 
LIMIT 10
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT room_type, unit_count 
FROM gold_supply_stats
-- Out:
-- Databricks visualization. Run in Databricks to view.
